# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepmohamed666/ICTAK_B9_Python-Case-Study/blob/main/dsa_b9_intermediate_assessment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    # Read file content
    with open(filename, 'r') as f:
        text = f.read()

    # Convert to lowercase and extract words (ignore punctuation)
    words = re.findall(r'\b[a-zA-Z]+\b', text.lower())

    # Count word frequencies
    freq = Counter(words)

    # Sort by frequency (descending), then alphabetically
    sorted_words = sorted(freq.items(), key=lambda x: (-x[1], x[0]))

    # Return top k words
    return [word for word, count in sorted_words[:k]]


# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  # expected ["is", "data", "science"]
# Out:
# ['is', 'data', 'evolving']

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        # Store category-wise total
        if category in expenses:
            expenses[category] += amount
        else:
            expenses[category] = amount

    # Calculate total expense
    total = sum(expenses.values())

    # Find highest expense category
    highest_category = max(expenses, key=expenses.get)

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)


# Run the function
analyze_expenses()
# Out:
# Enter number of transactions: 4
# Food 200
# Travel 500
# Food 300
# Shopping 700
# Total Expense: 1700.0
# Highest Category: Shopping
# Category-wise: {'Food': 500.0, 'Travel': 500.0, 'Shopping': 700.0}

# %% [markdown]
# ## Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)

            # Ignore negative values
            if num < 0:
                continue

            data.append(num)

        except:
            # Handle invalid values (ignore them)
            continue

    # Calculate average (avoid division by zero)
    if data:
        avg = sum(data) / len(data)
        max_val = max(data)
    else:
        avg = 0
        max_val = None

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)


# Run the function
clean_data()
# Out:
# Enter number of values: 6
# 10
# 20
# abc
# 30
# -5
# 40
# Clean Data: [10.0, 20.0, 30.0, 40.0]
# Average: 25.0
# Max: 40.0
